# %% [markdown]
# ## Libraries

# %%
import wfdb

header = wfdb.rdheader("04015", pn_dir="afdb/1.0.0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 import wfdb
#       3 header = wfdb.rdheader("04015", pn_dir="afdb/1.0.0")
# ----> 4 header.columns
#
# AttributeError: 'Record' object has no attribute 'columns'

# %%
import pandas as pd 
import numpy as np 
import wfdb
